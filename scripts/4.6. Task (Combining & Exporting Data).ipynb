# %% [markdown]
# # 4.6 Combining & Exporting Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing products data set
# ### 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Defining a path
path = r'/Users/hectorvargas/Desktop/Career_Foundry/11-2022 Instacart Basket Analysis'

# %%
# Importing "orders_products_combined.pkl" * orders_products_combined = df_orders_PC
df_orderspc = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ### 4.Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
# Checking shape of "df_orderspc"
df_orderspc.shape
# Out:
# (32434489, 12)

# %%
df_orderspc.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
# Droping column "Unnamed and Merge columns"
df_orderspc = df_orderspc.drop(df_orderspc.columns[[0,11]], axis = 1)

# %%
df_orderspc
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# df_orderspc Shape
df_orderspc.shape
# Out:
# (32434489, 10)

# %% [markdown]
# ### Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# Importing "products_checked2.csv"
df_prods_cleaned = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods_cleaned
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Droping column "Unnamed columns"
df_prods_cleaned = df_prods_cleaned.drop(df_prods_cleaned.columns[[0]], axis = 1)

# %%
df_prods_cleaned
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# df_prods_cleaned Shape
df_prods_cleaned.shape
# Out:
# (49672, 5)

# %% [markdown]
# ## Merging 2 DataFrames: 'orders_products_combined.pkl' and 'products_cleaned.csv'.

# %%
# Mergin both dataframes
df_orderspc_merged = df_orderspc.merge(df_prods_cleaned, on = 'product_id', indicator = True)

# %% [markdown]
# ## Resulst confirmation

# %%
df_orderspc_merged.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
# 5   3367565        1    prior             6                   2
# 6    550135        1    prior             7                   1
# 7   3108588        1    prior             8                   1
# 8   2295261        1    prior             9                   1
# 9   2550362        1    prior            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# ...

# %%
# Value Counts
df_orderspc_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# df_orderspc Shape
df_orderspc_merged.shape
# Out:
# (32404859, 15)

# %% [markdown]
# ## Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# Export data frame to PKL
df_orderspc_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4.6.pkl'))
