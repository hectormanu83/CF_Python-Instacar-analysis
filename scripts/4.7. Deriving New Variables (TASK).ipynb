# %% [markdown]
# # 4.7 Task

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining a path
path = r'/Users/hectorvargas/Desktop/Career_Foundry/11-2022 Instacart Basket Analysis'

# %%
# Import data frame to PKL
orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_4.6.pkl'))

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# Define function
def add_num (x,y):
    sum = x + y
    return sum

# %%
# Run function
add_num (9, 11)
# Out:
# 20

# %%
# The first one million roes
df = orders_products_merged[:1000000]

# %% [markdown]
# df.shape

# %% [markdown]
# # If-Statements with User-Defined Functions

# %%
# Sorting products into price ranges

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply "price ranges" function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/lp/xpk9x_2d0ys74t69nxfgqd700000gp/T/ipykernel_51157/360976033.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Values counts
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Checking the max price
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If-Statements with the loc() Function

# %%
# Df.loc funtion on price range
orders_products_merged.loc[orders_products_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
orders_products_merged.loc[(orders_products_merged['prices'] <= 15) & (orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
orders_products_merged.loc[orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
orders_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # If-Statements with For-Loops

# %%
for x in range(30,45):
    print("Mi edad es %d" % (x))
# Out:
# Mi edad es 30
# Mi edad es 31
# Mi edad es 32
# Mi edad es 33
# Mi edad es 34
# Mi edad es 35
# Mi edad es 36
# Mi edad es 37
# Mi edad es 38
# Mi edad es 39
# Mi edad es 40
# Mi edad es 41
# Mi edad es 42
# Mi edad es 43
# Mi edad es 44

# %%
# Printing frecuency of the “orders_day_of_the_week”
orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Looping the "busiest_day of the week"
result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Creating a new Column
orders_products_merged['busiest_day'] = result

# %%
orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# # Task 4.7

# %% [markdown]
# ## Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural).

# %%
#Creating the new Column
orders_products_merged['busiest_days'] = result

# %%
orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
#Checking the values of 'busiest_day'
orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_days, dtype: int64

# %%
# Looping for the busiest days of the week 
result1 = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Low day',
#  'Low day',
#  'Lowest busy',
#  'Lowest busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Lowest busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Lowest busy',
#  'Low day',
#  'Low day',
#  'Low day',
#  'Lowest busy',
#  'Lowest busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Low day',
#  'Regularly busy',
#  'Low day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Low day',
#  'Low day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Lowest busy',
# ...

# %%
len(result)
# Out:
# 162024295

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
#Checking the values of 'busiest_days'
orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_days, dtype: int64

# %% [markdown]
# ### When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Checking hours of the day
busiest_hours = orders_products_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
orders_products_merged["order_hour_of_day"].describe()
# Out:
# count    3.240486e+07
# mean     1.342515e+01
# std      4.246380e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
busiest_hours
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
busiest_hours = []

for value in orders_products_merged["order_hour_of_day"]:
  if (value >9  & value < 17):
    busiest_hours.append("Most orders")
  elif (value <7):
    busiest_hours.append("Fewest orders")
  else:
    busiest_hours.append("Average orders")

# %%
busiest_hours
# Out:
# ['Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
#Creating a new Column
orders_products_merged['busiest_period_of_day'] = busiest_hours

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# Dropping column "busiest_period_of_day2"
orders_products_merged = orders_products_merged.drop('busiest_period_of_day2', axis=1)

# %%
orders_products_merged
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
len(busiest_hours)
# Out:
# 32404859

# %%
#Print the frecuency for the new column
orders_products_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       27898069
# Average orders     4172321
# Fewest orders       334469
# Name: busiest_period_of_day, dtype: int64

# %%
#Print the frecuency for the new column
orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_days, dtype: int64

# %% [markdown]
# ## Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.
